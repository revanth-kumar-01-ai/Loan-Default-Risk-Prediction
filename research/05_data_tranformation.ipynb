# %% [markdown]
# ##### Note: You can add different data transformation techniques such as scaling, PCA, and more.
# ##### You can perform all kinds of EDA in the ML cycle here before passing this data to the model.
# #### **Sorry**, friends! I have already performed data transformation earlier. Now, I am only adding train-test splitting because this data is already cleaned.

# %%
import os 
import  warnings

import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

from loan_default_risk.constants import CONFIG_FILE_PATH

from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# %%
os.chdir('../')

# %%
df = pd.read_csv('artifacts/data_preprocessing/preprocessedDataset.csv')

# %%
df.head()
# Out:
#    numeric__months_loan_duration  numeric__amount  numeric__percent_of_income  \
# 0                       0.023256         0.050567                    1.000000
# 1                       0.441860         0.313690                    0.333333
# 2                       0.093023         0.101574                    0.333333
# 3                       0.441860         0.419941                    0.333333
# 4                       0.232558         0.254209                    0.666667
#
#    numeric__years_at_residence  numeric__age  numeric__existing_loans_count  \
# 0                     1.000000      0.812500                       0.333333
# 1                     0.333333      0.053571                       0.000000
# 2                     0.666667      0.535714                       0.000000
# 3                     1.000000      0.464286                       0.000000
# 4                     1.000000      0.607143                       0.333333
#
# ...

# %%
independent = df.drop(columns = 'categorical__default_yes')

dependent = df['categorical__default_yes']

# %%
dependent.value_counts(normalize = True) # The dataset balanced (note if less than thirty percentage means is imbalanced now if tha dataset is balanced)
# Out:
# categorical__default_yes
# 0.0    0.7
# 1.0    0.3
# Name: proportion, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.2, random_state = 0)

# %%
y_test.value_counts()
# Out:
# categorical__default_yes
# 0.0    142
# 1.0     58
# Name: count, dtype: int64

# %%
train, test = train_test_split(df) # save this two train and test
